# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# *	Resolver el siguiente trabajo en un nootebook de Python usando Google Colab, Deepnote o similar.
# *	Guardar el archivo `*.ipynb` y nombrar el archivo con sus nombres y apellidos (Nombre1Apellido1_ Nombre2Apellido2).
# *	Entregar el trabajo en parejas y enviarlo al correo electrónico `estebangonzalez4302@correo.itm.edu.co`.
#
# El objetivo de este taller es aplicar concepto básicos de ciencia de datos, como la inspección inicial de un dataset, la limpieza de los datos, la búsqueda de relaciones entre variables y un análisis de reducción de dimensionalidad.

# %% [markdown]
# # **Limpieza y Preparación de Datos - NYC Airbnb**
#
# Para ese taller, usaremos el dataset "**NYC Airbnb Open Data**" disponible en la plataforma [kaggle](https://www.kaggle.com/datasets/yousefmohamed20/ab-nyc-2019?resource=download).
#
# Para comenzar, utilizaremos la librería `kagglehub` de Python para cargar el dataset directamente en un DataFrame de pandas:
#
# Este conjunto de datos incluye información detallada sobre las publicaciones de Airbnb en los cinco distritos de Nueva York. Es ideal para practicar la identificación de valores nulos (especialmente en nombres y fechas), el manejo de tipos de datos incorrectos y la preparación de variables para un análisis exploratorio.

# %% [markdown]
# ## **1. IDENTIFICACIÓN DE TIPOS DE DATOS E INSPECCIÓN INICIAL**
#
# Información inicial del DataFrame y conteo de nulos:

# %% [markdown]
# **1.1** Realice la carga del dataset AB_NYC_2019.csv utilizando la librería Pandas.

# %%
# Importar las librerías necesarias
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import kagglehub
from kagglehub import KaggleDatasetAdapter

# %% [markdown]
# **1.2** Realice la carga del dataset AB_NYC_2019.csv utilizando la librería Pandas.

# %%
# Cargar la última versión de Dataset )
datos = kagglehub.load_dataset(KaggleDatasetAdapter.PANDAS,"yousefmohamed20/ab-nyc-2019","AB_NYC_2019.csv",)

# Mostrar las primeras filas del dataset
datos.head()

# NOTA: Si desea puede cambiarle el nombre 'datos' por el que prefiera

# %% [markdown]
# **1.3** Utilice los métodos `.info()` y `.shape` para determinar la cantidad de registros y el tipo de dato por columna.

# %%
# Agregue el código en esta sección:

# %% [markdown]
# **1.2** Realice un perfilado estadístico inicial de las variables numéricas con `.describe()`. Identifique si existen valores inconsistentes (por ejemplo, precios, disponibilidad o cantidad de noches en cero o negativos).

# %%
# Agregue el código en esta sección:

# %% [markdown]
# ## ***2. LIMPIEZA DE VALORES FALTANTES**

# %% [markdown]
# **2.1.**  Identifique la cantidad de valores nulos por columna utilizando `.isnull().sum()`. Calcule el porcentaje de valores nulos por columna.

# %%
# Agregue el código en esta sección:

# %% [markdown]
# **2.2.**  Criterio de eliminación: Las columnas `name` y `host_name` presentan pocos valores faltantes. Proceda a eliminar únicamente las filas que contienen nulos en estas columnas.

# %%
# Agregue el código en esta sección:

# %% [markdown]
# **2.3.**  Criterio de imputación: La columna `reviews_per_month` presenta un alto número de nulos. Asuma que si no hay registro, es porque la propiedad NO tiene reseñas. Impute estos valores con `0`.

# %%
# Agregue el código en esta sección:

# %% [markdown]
# **2.4.** Evalúe la columna `last_review`. ¿Es conveniente eliminar la columna completa o solo los registros nulos? Justifique su respuesta basándose en la integridad del dataset.

# %% [markdown]
# *(Doble click para añadir su respuesta)*

# %% [markdown]
# **2.5.** Identifique columnas que actúen únicamente como identificadores o metadatos descriptivos que no aporten al análisis estadístico (por ejemplo, códigos de identificación, nombres, etc.). Elimine estas columnas.

# %%
# Agregue el código en esta sección:

# %% [markdown]
# ## **3. TRANSFORMACIÓN Y CORRECCIÓN DE ERRORES ESTRUCTURALES**

# %% [markdown]
# **3.1.** La columna `last_review` se carga originalmente como tipo **object** y no como . Convietala a formato datetime utilizando `pd.to_datetime(datos['last_review'])`. Verifique que el cambio fue realizado correctamente usando nuevamente `info()`.

# %%
# Agregue el código en esta sección:

# %% [markdown]
# **3.2.** Verifique que no existan registros duplicados. En caso de existir, elimine los duplicados manteniendo el primer registro encontrado.

# %%
# Agregue el código en esta sección:

# %% [markdown]
# ## **4. DETECCION Y TRATAMIENTO DE ATÍPICOS (OUTLIERS)**

# %% [markdown]
# **4.1.**	Utilice un Boxplot para analizar la distribución de la variable `price`. Identifique visualmente si existen valores que se alejan drásticamente del promedio.

# %%
# Agregue el código en esta sección:

# %% [markdown]
# **4.2.** Aplique un filtro para trabajar con un rango de precios razonable, donde se excluyan las propiedades con precios **exageradamente grandes **o **exageradamente pequeños**.
#
# El comando para filtrar la columna deprecios por un valor es: `datos = datos[(datos['price'] <= valor)]`
#
# donde `<=` es la condición para poner un límite máximo,  `>=` es la condición para poner un límite mínimo y `valor` será el ese precio que quiera usarse según el caso

# %%
# Agregue el código en esta sección:

# %% [markdown]
# ## **5. CODIFICACIÓN DE VARIABLES CATEGÓRICAS**

# %% [markdown]
# **5.1.** La columna `neighbourhood_group` tiene como categorías únicas:
#   - Brooklyn
#   - Manhattan
#   - Queens
#   - Staten Island
#   - Bronx
#
# De forma similar al  ejemplo del tratamiento a la columna `Sex` del ejemplo con el dataset **'Titanic'**, realice un mapeo numérico (Label Encoding) para la columna `neighbourhood_group` asignando un valor entero a cada distrito.

# %%
# Agregue el código en esta sección:

# %% [markdown]
# **5.2.**	De manera similar a como se trabajó con la variable Embarked en el caso del **Titanic**, aplique la técnica de One-Hot Encoding (variables dummy) para la columna `room_type`, usando como prefijo la palabra `type`.
#
#
# Las categorías única de la columna `neighbourhood_group` son:
#   - Private room
#   - Entire home/apt
#   - Shared room

# %%
# Agregue el código en esta sección:

# %% [markdown]
# ## **6. MATRIZ DE CORRELACIÓN**

# %% [markdown]
# **6.1.** Seleccione únicamente las variables numéricas relevantes (excluyendo IDs y coordenadas).

# %%
# Agregue el código en esta sección:

# %% [markdown]
# **6.2** Calcule la matriz de correlación de Pearson utilizando el método `.corr()`.

# %%
# Agregue el código en esta sección:

# %% [markdown]
# **6.3**	Genere un mapa de calor (heatmap) con Seaborn que incluya las anotaciones numéricas.

# %%
# Agregue el código en esta sección:

# %% [markdown]
# **6.4.** Analice si existe alguna relación fuerte entre el número de reseñas (`number_of_reviews`) y la disponibilidad de la propiedad (`availability_365`)

# %% [markdown]
# *(Doble click para añadir su respuesta)*

# %% [markdown]
# ## **7. ANÁLISIS VISUAL Y EXPLORATORIO DE LOS DATOS (LIMPIOS)**

# %% [markdown]
# **8.1** Realiza un gráfico donde se vea se distribuyen los precios de los alojamientos en la ciudad una vez eliminados los valores atípicos. Utilice un parámetro de bins=50 y agregue una línea de densidad (KDE).

# %%
# Agregue el código en esta sección:

# %% [markdown]
# * ¿Es una distribución simétrica o sesgada? ¿En qué rango de precio se concentra la mayor parte de la oferta?

# %% [markdown]
# *(Doble click para añadir su respuesta)*

# %% [markdown]
# **8.2.** Realice un boxplot donde el eje X sea `neighbourhood_group` y el eje Y sea `price`.

# %%
# Agregue el código en esta sección:

# %% [markdown]
# * Identifique visualmente qué distrito tiene la mediana más alta y en cuál se encuentran los alojamientos de lujo (outliers superiores) más extremos.

# %% [markdown]
# *(Doble click para añadir su respuesta)*

# %% [markdown]
# **8.3.** Genere un gráfico de violín para analizar cómo influye el tipo de alojamiento (`room_type`) en la disponibilidad de la propiedad a lo largo del año (`availability_365`)?

# %%
# Agregue el código en esta sección:

# %% [markdown]
# * Observe la "anchura" del violín. ¿Existen tipos de habitación que suelen estar disponibles todo el año (cerca de 365) o que son extremadamente temporales (cerca de 0)?

# %% [markdown]
# *(Doble click para añadir su respuesta)*

# %% [markdown]
# **8.4.** Cree un gráfico de dispersión (scatter plot) relacionando el precio del alojamiento (eje X) y el número de reviews (eje Y).

# %%
# Agregue el código en esta sección:

# %% [markdown]
# * ¿Se observa alguna tendencia? (Por ejemplo: a mayor precio, ¿disminuye el volumen de reseñas?). Reflexione sobre si el precio es una barrera para la rotación de clientes.

# %% [markdown]
# *(Doble click para añadir su respuesta)*

# %% [markdown]
# **8.5.** Grafique la `longitude` en el eje X y la `latitude` en el eje Y. Utilice el parámetro `hue='price'` para colorear los puntos según su costo.

# %%
# Agregue el código en esta sección:

# %% [markdown]
# * ¿Se puede identificar visualmente la zona de Manhattan o las zonas más costosas de Brooklyn a través de este mapa de puntos?

# %% [markdown]
# *(Doble click para añadir su respuesta)*
